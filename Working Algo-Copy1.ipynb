# %%
# Loading up libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading up csv
df = pd.read_csv(r"./csv/data_3600.csv")

# %%
SMAL = df['Price'].rolling(window = 5).mean()
SMAH = df['Price'].rolling(window = 25).mean()

# %%
df["SMAL"] = SMAL
df["SMAH"] = SMAH
df["Change"] = ""
df["Buy/Sell"] = ""
df["TimeLimit"] = 0
df["isAllowed"] = False
df["Action"] = "---"

# %%
def checkCrossover(row):
    if row["SMAL"] > row["SMAH"]:
        return "Higher"
    else:
        return "Lower"

# %%
df["Crossover"] = df.apply(checkCrossover, axis=1)

# %%
for index, row in df.iterrows():
    if index == 0:
        df["Change"][index] = "N/A"
    else:
        if df["Crossover"][index] == df["Crossover"][index-1]:
            df["Change"][index] = "---"
        else:
            df["Change"][index] = "Crossed"

for index, row in df.iterrows():
    if index == 0:
        df["Buy/Sell"][index] = True
    else:
        __currentMode = df["Buy/Sell"][index - 1]
        df["Buy/Sell"][index] = __currentMode
        if df["Change"][index] == "Crossed":
            df["Buy/Sell"][index] = not __currentMode


            
# for index, row in df.iterrows():
#     if index == 0:
#         df["TimeLimit"][index] = 0
#     else:
# Out:
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2546903424.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Change"][index] = "N/A"
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2546903424.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Change"][index] = "---"
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2546903424.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Change"][index] = "Crossed"
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2546903424.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Buy/Sell"][index] = True
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2546903424.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Buy/Sell"][index] = __currentMode
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2546903424.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Buy/Sell"][index] = not __currentMode

# %%
for index, row in df.iterrows():
    if index == 0:
        df["TimeLimit"][index] = 0
    else:
        __TimeLimit = df["TimeLimit"][index - 1]
        __isAllowed = df["isAllowed"][index - 1]
        df["TimeLimit"][index] = __TimeLimit + 1
        if df["TimeLimit"][index] > 60:
            df["TimeLimit"][index] = 0
        if df["TimeLimit"][index] >= 30 and df["TimeLimit"][index] <= 60:
            df["isAllowed"][index] = True
        else:
            df["isAllowed"][index] = False


for index, row in df.iterrows():
    if index == 0:
        df["Action"][index] = "Buy!"
    if df["isAllowed"][index] and df["Change"][index] == "Crossed":
        if df["Buy/Sell"][index]:
            df["Action"][index] = "Buy!"
        else:
            df["Action"][index] = "Sell!"
        df["TimeLimit"][index] = 0
# Out:
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2751888581.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TimeLimit"][index] = 0
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2751888581.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TimeLimit"][index] = __TimeLimit + 1
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2751888581.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["isAllowed"][index] = False
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2751888581.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["isAllowed"][index] = True
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2751888581.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TimeLimit"][index] = 0
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2751888581.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Action"][index] = "Buy!"
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2751888581.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Action"][index] = "Sell!"
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2751888581.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TimeLimit"][index] = 0
# /var/folders/gf/px41l6s15f3fffhq5nk6h4f80000gp/T/ipykernel_17673/2751888581.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Action"][index] = "Buy!"

# %%
df[0:60]
# Out:
#     Time   Price     SMAL      SMAH   Change Buy/Sell  TimeLimit  isAllowed  \
# 0      0  1.2546      NaN       NaN      N/A     True          0      False
# 1      1  1.2567      NaN       NaN      ---     True          1      False
# 2      2  1.2577      NaN       NaN      ---     True          2      False
# 3      3  1.2579      NaN       NaN      ---     True          3      False
# 4      4  1.2593  1.25724       NaN      ---     True          4      False
# 5      5  1.2668  1.25968       NaN      ---     True          5      False
# 6      6  1.2695  1.26224       NaN      ---     True          6      False
# 7      7  1.2689  1.26448       NaN      ---     True          7      False
# 8      8  1.2679  1.26648       NaN      ---     True          8      False
# 9      9  1.2679  1.26820       NaN      ---     True          9      False
# 10    10  1.2678  1.26840       NaN      ---     True         10      False
# 11    11  1.2661  1.26772       NaN      ---     True         11      False
# 12    12  1.2724  1.26842       NaN      ---     True         12      False
# 13    13  1.2702  1.26888       NaN      ---     True         13      False
# 14    14  1.2661  1.26852       NaN      ---     True         14      False
# 15    15  1.2672  1.26840       NaN      ---     True         15      False
# 16    16  1.2676  1.26870       NaN      ---     True         16      False
# 17    17  1.2664  1.26750       NaN      ---     True         17      False
# 18    18  1.2662  1.26670       NaN      ---     True         18      False
# 19    19  1.2635  1.26618       NaN      ---     True         19      False
# 20    20  1.2671  1.26616       NaN      ---     True         20      False
# 21    21  1.2714  1.26692       NaN      ---     True         21      False
# 22    22  1.2704  1.26772       NaN      ---     True         22      False
# 23    23  1.2682  1.26812       NaN      ---     True         23      False
# 24    24  1.2686  1.26914  1.265856  Crossed    False         24      False
# 25    25  1.2673  1.26918  1.266364      ---    False         25      False
# 26    26  1.2655  1.26800  1.266716      ---    False         26      False
# 27    27  1.2661  1.26714  1.267052      ---    False         27      False
# 28    28  1.2639  1.26628  1.267292  Crossed     True         28      False
# 29    29  1.2654  1.26564  1.267536      ---     True         29      False
# 30    30  1.2636  1.26490  1.267408      ---     True         30       True
# 31    31  1.2617  1.26414  1.267096      ---     True         31       True
# 32    32  1.2596  1.26284  1.266724      ---     True         32       True
# 33    33  1.2583  1.26172  1.266340      ---     True         33       True
# 34    34  1.2562  1.25988  1.265872      ---     True         34       True
# 35    35  1.2596  1.25908  1.265544      ---     True         35       True
# 36    36  1.2630  1.25934  1.265420      ---     True         36       True
# 37    37  1.2634  1.26010  1.265060      ---     True         37       True
# 38    38  1.2633  1.26110  1.264784      ---     True         38       True
# 39    39  1.2637  1.26260  1.264688      ---     True         39       True
# 40    40  1.2629  1.26326  1.264516      ---     True         40       True
# 41    41  1.2606  1.26278  1.264236      ---     True         41       True
# 42    42  1.2612  1.26234  1.264028      ---     True         42       True
# 43    43  1.2602  1.26172  1.263788      ---     True         43       True
# 44    44  1.2590  1.26078  1.263608      ---     True         44       True
# 45    45  1.2620  1.26060  1.263404      ---     True         45       True
# 46    46  1.2629  1.26106  1.263064      ---     True         46       True
# 47    47  1.2647  1.26176  1.262836      ---     True         47       True
# 48    48  1.2657  1.26286  1.262736  Crossed    False          0       True
# 49    49  1.2676  1.26458  1.262696      ---    False         49       True
# 50    50  1.2653  1.26524  1.262616      ---    False         50       True
# 51    51  1.2703  1.26672  1.262808      ---    False         51       True
# 52    52  1.2707  1.26792  1.262992      ---    False         52       True
# 53    53  1.2723  1.26924  1.263328      ---    False         53       True
# 54    54  1.2705  1.26982  1.263532      ---    False         54       True
# 55    55  1.2681  1.27038  1.263712      ---    False         55       True
# 56    56  1.2696  1.27024  1.264028      ---    False         56       True
# 57    57  1.2711  1.27032  1.264488      ---    False         57       True
# 58    58  1.2796  1.27178  1.265340      ---    False         58       True
# 59    59  1.2788  1.27344  1.266244      ---    False         59       True
#
#    Action Crossover
# 0    Buy!     Lower
# 1     ---     Lower
# 2     ---     Lower
# 3     ---     Lower
# 4     ---     Lower
# 5     ---     Lower
# 6     ---     Lower
# 7     ---     Lower
# 8     ---     Lower
# 9     ---     Lower
# 10    ---     Lower
# 11    ---     Lower
# 12    ---     Lower
# 13    ---     Lower
# 14    ---     Lower
# 15    ---     Lower
# 16    ---     Lower
# 17    ---     Lower
# 18    ---     Lower
# 19    ---     Lower
# 20    ---     Lower
# 21    ---     Lower
# 22    ---     Lower
# 23    ---     Lower
# 24    ---    Higher
# 25    ---    Higher
# 26    ---    Higher
# 27    ---    Higher
# 28    ---     Lower
# 29    ---     Lower
# 30    ---     Lower
# 31    ---     Lower
# 32    ---     Lower
# 33    ---     Lower
# 34    ---     Lower
# 35    ---     Lower
# 36    ---     Lower
# 37    ---     Lower
# 38    ---     Lower
# 39    ---     Lower
# 40    ---     Lower
# 41    ---     Lower
# 42    ---     Lower
# 43    ---     Lower
# 44    ---     Lower
# 45    ---     Lower
# 46    ---     Lower
# 47    ---     Lower
# 48  Sell!    Higher
# 49    ---    Higher
# 50    ---    Higher
# 51    ---    Higher
# 52    ---    Higher
# 53    ---    Higher
# 54    ---    Higher
# 55    ---    Higher
# 56    ---    Higher
# 57    ---    Higher
# 58    ---    Higher
# 59    ---    Higher
